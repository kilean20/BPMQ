# %%
import sys
sys.path.append('../')

from BPMQ import *
import numpy as np

# %%
machineIO = construct_machineIO()
machineIO._test = True
machineIO._check_chopper_blocking = False
machineIO._fetch_data_time_span = 1
machineIO._ensure_set_timewait_after_ramp = 0.25
machineIO._fetch_data_resample_rate = 0.2

E_MeVu = 130
Mass_number = 18
Charge_number = 8

# %% [markdown]
# # preprare BPMQ scan

# %%
# Example usage (assuming you have the helper functions defined as before):
filename = "lattice.txt"  # Replace with your lattice file
from_elem = "BDS_BTS:QV_D5501"
to_elem = "BDS_BTS:PM_D5567"
lattice_dicts = fmlat.combine_lattice_elements_quads_only(filename, from_element=from_elem, to_element=to_elem)
for elem_dic in lattice_dicts:
    elem_dic['name'] = fmlat.fmname2mpname(elem_dic['name'])
#, line_name = "cell")
# qnames = ["BDS_BTS:PSQ_D5501", "BDS_BTS:PSQ_D5509", "BDS_BTS:PSQ_D5552", "BDS_BTS:PSQ_D5559"]
qnames = [elem['name'] for elem in lattice_dicts if elem['type']=='quadrupole']
qnames = qnames[-4:]
qnames
# Out:
# ['BDS_BTS:PSQ_D5501',
#  'BDS_BTS:PSQ_D5509',
#  'BDS_BTS:PSQ_D5552',
#  'BDS_BTS:PSQ_D5559']

# %%
args = (E_MeVu, Mass_number, Charge_number)
kwargs = {
    "quads_to_scan": qnames,
    "quads_max_curr": [180, 180, 180, 180],
    "quads_min_curr": [ 10,  10,  10,  10],
    "BPM_names": ["BDS_BTS:BPM_D5513", "BDS_BTS:BPM_D5565"],
    "lattice_dicts" : lattice_dicts,
    "xnemit_target": None,
    "ynemit_target": None,
    "ISAAC_preset_keywords":["BDS"],
    "bootstrap":False,
    "machineIO": None,
    "plot_history":True, 
    "plot_ellipse":True,
}

# %% [markdown]
# # Run for various virtual Qerrs

# %%
start_time = time.monotonic()
bpmQscan = BPMQscan(*args, **kwargs, 
                    virtual_beamQerr=0.0)
bpmQscan.run(budget=12)
print(f"CS sol difference from ref: {bpmQscan.model.cs - bpmQscan.cs_ref}")
elapsed_time_minutes = (time.monotonic() - start_time) / 60
print(f"Elapsed time: {elapsed_time_minutes:.2f} minutes")
l_xcovs, l_ycovs = fmlat.update_lattice_file_from_bpmQscan(filename,bpmQscan)
# Out:
# ISAAC preset:
#    BDS_BTS:PSQ_D5501:I_CSET  BDS_BTS:PSQ_D5509:I_CSET
# 0                 60.079875                 46.937402
# 1                 60.079875                 64.530236
# 2                 60.079875                 82.123070
# 3                 60.079875                 99.715904
# 4                 60.079875                117.308737
# 5                123.149836                 66.407732
# 6                 99.715904                 66.407732
# 7                 76.212434                 66.407732
# 8                 52.778501                 66.407732
# 9                 29.344569                 66.407732
# init_llB2 tensor([[-10.8047,  11.4771, -16.6618,  18.4713],
#         [ 60.0799,  46.9374, -16.6618,  18.4713],
#         [ 60.0799,  64.5302, -16.6618,  18.4713],
#         [ 60.0799,  82.1231, -16.6618,  18.4713],
#         [ 60.0799,  99.7159, -16.6618,  18.4713],
#         [ 60.0799, 117.3087, -16.6618,  18.4713],
#         [123.1498,  66.4077, -16.6618,  18.4713],
#         [ 99.7159,  66.4077, -16.6618,  18.4713],
#         [ 76.2124,  66.4077, -16.6618,  18.4713],
#         [ 52.7785,  66.4077, -16.6618,  18.4713],
#         [ 29.3446,  66.4077, -16.6618,  18.4713]])
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# after init, number of training data is 1
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Early stopping at iteration 136 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 216 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 120 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 142 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-11.0723)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-13.4267)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-6.4618)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
# [Warning] Beam loss detected!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 150 due to loss stabilization.
# Early stopping at iteration 132 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-5.4990)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 141 due to loss stabilization.
# best_loss tensor(-0.3194)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.8940)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.8262)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.7984)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Early stopping at iteration 110 due to loss stabilization.
# Early stopping at iteration 210 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 159 due to loss stabilization.
# Early stopping at iteration 123 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.9433)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 141 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 122 due to loss stabilization.
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 112 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# best_loss tensor(450.9294)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 112 due to loss stabilization.
# Early stopping at iteration 122 due to loss stabilization.
# Early stopping at iteration 110 due to loss stabilization.
# best_loss tensor(0.9459)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 137 due to loss stabilization.
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.9734)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.9743)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
# Queries keep seeing beam loss. Stopping after collection of 9 train data.
# CS sol difference from ref: tensor([ 9.1255e-04,  1.0780e-02, -2.4880e-10,  7.2002e-05,  5.6531e-03,
#         -9.9845e-11])
# Elapsed time: 2.32 minutes

# %%
# check back-tracked result with flame
# l_xcovs, l_ycovs = fmlat.update_lattice_file_from_bpmQscan(filename,bpmQscan)
# xcov = l_xcovs[0,0].detach().numpy()
# ycov = l_ycovs[0,0].detach().numpy()

# from flame_utils import ModelFlame
# fm = ModelFlame(lat_file = filename)
# to_elem = "BDS_BTS:QV_D5501"
# r,s = fm.run(to_element=fm.get_index_by_name(to_elem)[to_elem][0]-1)

# %%
tart_time = time.monotonic()
bpmQscan = BPMQscan(*args, **kwargs, 
                    virtual_beamQerr=0.8)
bpmQscan.run(budget=12)
print(f"CS sol difference from ref: {bpmQscan.model.cs - bpmQscan.cs_ref}")
elapsed_time_minutes = (time.monotonic() - start_time) / 60
print(f"Elapsed time: {elapsed_time_minutes:.2f} minutes")
l_xcovs, l_ycovs = fmlat.update_lattice_file_from_bpmQscan(filename,bpmQscan)
# Out:
# ISAAC preset:
#    BDS_BTS:PSQ_D5501:I_CSET  BDS_BTS:PSQ_D5509:I_CSET
# 0                 60.079875                 46.937402
# 1                 60.079875                 64.530236
# 2                 60.079875                 82.123070
# 3                 60.079875                 99.715904
# 4                 60.079875                117.308737
# 5                123.149836                 66.407732
# 6                 99.715904                 66.407732
# 7                 76.212434                 66.407732
# 8                 52.778501                 66.407732
# 9                 29.344569                 66.407732
# init_llB2 tensor([[-10.8047,  11.4771, -16.6618,  18.4713],
#         [ 60.0799,  46.9374, -16.6618,  18.4713],
#         [ 60.0799,  64.5302, -16.6618,  18.4713],
#         [ 60.0799,  82.1231, -16.6618,  18.4713],
#         [ 60.0799,  99.7159, -16.6618,  18.4713],
#         [ 60.0799, 117.3087, -16.6618,  18.4713],
#         [123.1498,  66.4077, -16.6618,  18.4713],
#         [ 99.7159,  66.4077, -16.6618,  18.4713],
#         [ 76.2124,  66.4077, -16.6618,  18.4713],
#         [ 52.7785,  66.4077, -16.6618,  18.4713],
#         [ 29.3446,  66.4077, -16.6618,  18.4713]])
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# warning: invalid value encountered in scalar power
# warning: invalid value encountered in scalar power
# [Warning] BPMQ too large!
# after init, number of training data is 1
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 157 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 199 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 113 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-15.7971)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 114 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-7.9314)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 130 due to loss stabilization.
# Exiting early at iteration 2 due to large loss
# Early stopping at iteration 187 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-9.1569)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
# [Warning] Beam loss detected!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Early stopping at iteration 121 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 115 due to loss stabilization.
# best_loss tensor(-9.3015)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-8.1818)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.9313)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 184 due to loss stabilization.
# Early stopping at iteration 118 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# best_loss tensor(13287.6377)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.2977)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 146 due to loss stabilization.
# Early stopping at iteration 209 due to loss stabilization.
# Early stopping at iteration 110 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 117 due to loss stabilization.
# Early stopping at iteration 130 due to loss stabilization.
# best_loss tensor(1318.0018)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(-1.0461)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Early stopping at iteration 171 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.7265)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.9548)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
# [Warning] Beam loss detected!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Early stopping at iteration 138 due to loss stabilization.
# Early stopping at iteration 129 due to loss stabilization.
# Early stopping at iteration 151 due to loss stabilization.
# Early stopping at iteration 116 due to loss stabilization.
# best_loss tensor(0.9396)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.6067)
# best_regloss_beamloss 0.0
# [Warning] BPMQ too large!
#  ======== query_candidate_quad_set_maximizing_BPMQ_var ========
# Early stopping at iteration 110 due to loss stabilization.
# Early stopping at iteration 165 due to loss stabilization.
# Exiting early at iteration 1 due to large loss
# Exiting early at iteration 1 due to large loss
# best_loss tensor(0.7556)
# best_regloss_beamloss 0.0
#  ======== cs_reconstruct ========
# Queries keep seeing beam loss. Stopping after collection of 9 train data.
#  [IMPORTANT] population of reconstructed ellipses are not yet converged
# CS sol difference from ref: tensor([ 3.8747e-02, -1.7754e-01,  1.7749e-09, -1.8593e-01,  3.8417e-01,
#         -1.7420e-08])
# Elapsed time: 3.38 minutes
